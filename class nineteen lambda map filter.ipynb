# %%
def add(x,y):
    return x + y

# %%
add(8,2)
# Out:
# 10

# %%
add(10,30)
# Out:
# 40

# %%
add1 = lambda x,y : x + y

# %%
add1(12,10)
# Out:
# 22

# %%
### map

# %%
x = [2,4,6]

# %%
x
# Out:
# [2, 4, 6]

# %%
for num in x:
    print(num * 2)
# Out:
# 4
# 8
# 12

# %%
y = []
for num in x:
    y.append(num * 2)

# %%
y
# Out:
# [4, 8, 12]

# %%
### map

# %%
## casting

# %%
x = "3.4"

# %%
x
# Out:
# '3.4'

# %%
type(x)
# Out:
# str

# %%
float(x)
# Out:
# 3.4

# %%
x = [1,2,3,4]

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
type(x)
# Out:
# list

# %%
tuple(x)
# Out:
# (1, 2, 3, 4)

# %%
set(x)
# Out:
# {1, 2, 3, 4}

# %%
#### map

# %%
x = [2,4,6]

# %%
x
# Out:
# [2, 4, 6]

# %%
def multiply2(num):
    return num * 3

# %%
multiply2(7)
# Out:
# 21

# %%
map(multiply2,x) ##>>> map apply function to iterable

# %%
list(map(multiply2,x))#, list convert the map object to a list to display the result
# Out:
# [6, 12, 18]

# %%
names = ["mrs ade" , "mr james" , "bro deji"]

# %%
names
# Out:
# ['mrs ade', 'mr james', 'bro deji']

# %%
type(names)
# Out:
# list

# %%
def convert(value):
    return value.upper()

# %%
## map(function , iterable)

# %%
map(convert , names)

# %%
list(map(convert , names))
# Out:
# ['MRS ADE', 'MR JAMES', 'BRO DEJI']

# %%
## iterable involves list , tuple , string , set

# %%
x = "deji"

x[0]
# Out:
# 'd'

# %%
x[1]
# Out:
# 'e'

# %%
for w in x:
    print(w)
# Out:
# d
# e
# j
# i

# %%
convert("deji")
# Out:
# 'DEJI'

# %%
map(convert,names) ### map apply function to iterable

# %%
list(map(convert,names))
# Out:
# ['MRS ADE', 'MR JAMES', 'BRO DEJI']

# %%
### 
x = [1,2,3]

# %%
x
# Out:
# [1, 2, 3]

# %%
def double(num):
    return num * num

# %%
double(2)
# Out:
# 4

# %%
double(5)
# Out:
# 25

# %%
map(double , x )

# %%
list(map(double , x ))
# Out:
# [1, 4, 9]
