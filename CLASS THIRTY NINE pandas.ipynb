# %%
import pandas as pd
import numpy as np

# %%
### pandas is for data manipulation and analysis

# %%
### two data types
### >>> series 
### >>>  Dataframe

# %%
x = ['deji','mrs ade','mr james','mr philip'] ## list of name

# %%
arr = np.array(x) ## coverting name list to numpy array
arr
# Out:
# array(['deji', 'mrs ade', 'mr james', 'mr philip'], dtype='<U9')

# %%
ser = pd.Series(x,name="users") ### converting name list to pandas series
ser
# Out:
# 0         deji
# 1      mrs ade
# 2     mr james
# 3    mr philip
# Name: users, dtype: object

# %%
amount = [10,20,30,40] ### list of numbers

# %%
ser1 = pd.Series(amount,name="salary")

# %%
ser1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: salary, dtype: int64

# %%
ser1.size
# Out:
# 4

# %%
ser1.shape
# Out:
# (4,)

# %%
ser1.mean()
# Out:
# 25.0

# %%
ser1.median()
# Out:
# 25.0

# %%
ser1.mode()
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: salary, dtype: int64

# %%
ser1.var()
# Out:
# 166.66666666666666

# %%
ser1.std()
# Out:
# 12.909944487358056

# %%
ser1.describe()
# Out:
# count     4.000000
# mean     25.000000
# std      12.909944
# min      10.000000
# 25%      17.500000
# 50%      25.000000
# 75%      32.500000
# max      40.000000
# Name: salary, dtype: float64

# %%
ser1.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4 entries, 0 to 3
# Series name: salary
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      int64
# dtypes: int64(1)
# memory usage: 164.0 bytes

# %%
### Dataframe

# %%
ser1.to_numpy() ### converting series to numpy
# Out:
# array([10, 20, 30, 40], dtype=int64)

# %%
arr2 = ser1.to_numpy() ### assigning it to variable name

# %%
arr2
# Out:
# array([10, 20, 30, 40], dtype=int64)

# %%
arr2.reshape((2,2)) ### reshaping to 2 x 2
# Out:
# array([[10, 20],
#        [30, 40]], dtype=int64)

# %%
arr3 = arr2.reshape((2,2)) ## storing it to a variable name 
arr3
# Out:
# array([[10, 20],
#        [30, 40]], dtype=int64)

# %%
### 
pd.DataFrame(arr3 , columns = ["amount1" , "amount2"]) ### use dataframe because its more than one columns
# Out:
#    amount1  amount2
# 0       10       20
# 1       30       40

# %%
### dataframe and how to read csv and other file with pandas
