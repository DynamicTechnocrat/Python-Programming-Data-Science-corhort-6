# %%
x = 7
y = 0

# %%
x  / y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x  / y
#
# ZeroDivisionError: division by zero

# %%
try:
    x = 7
    y = 0
    print(x/y)
except ZeroDivisionError:
    print("sir you can not divide by zero")
# Out:
# sir you can not divide by zero

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
try:
    name
except NameError:
    print("name is not assigned")
# Out:
# name is not assigned

# %%
x = "4"
int(x)
# Out:
# 4

# %%
y = "four"

int(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 y = "four"
# ----> 3 int(y)
#
# ValueError: invalid literal for int() with base 10: 'four'

# %%
try:
    y = "four"
    int(y)
except ValueError:
    print("you cannot convert a string to an integer or a float")
# Out:
# you cannot convert a string to an integer or a float

# %%
x = "five"
p
int(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 x = "five"
# ----> 2 p
#       3 int(x)
#
# NameError: name 'p' is not defined

# %%
try :
    x = "five"
    x + 9
except (NameError,ValueError,ZeroDivisionError,TypeError):
    print("invalid date")
# Out:
# invalid date

# %%
try :
    x = "five"
    int(x)
except :
    print("invalid data")
finally:
    print("code ran successfully")
# Out:
# invalid data
# code ran successfully

# %%
def add(x,y):
    return x + y

# %%
try:
 add("five",5)
except:
    print("wrong input")
# Out:
# wrong input

# %%
try :
    7 / 0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
int("deji")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 int("deji")
#
# ValueError: invalid literal for int() with base 10: 'deji'

# %%
try :
    int("deji")
except ValueError as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'deji'

# %%
try :
    int("deji")
except as e:
    print(e)
# Out:
#   Cell In[38], line 3
#     except as e:
#            ^
# SyntaxError: invalid syntax

# %%
try :
    7 /0 
except (ZeroDivisionError, ValueError,TypeError , NameError) as e:
    print(e)
# Out:
# division by zero

# %%
import builtins

# %%
import builtins

exceptions = [
    name for name, obj in vars(builtins).items()
    if isinstance(obj, type) and issubclass(obj, BaseException)
]

print(sorted(exceptions))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'NotADirectoryError', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning'
# ...

# %%
tuple(sorted(exceptions))
# Out:
# ('ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'NotADirectoryError',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
### Module , packages , Libraries
