# %%
### less than <
##, greater than > 
### and equal ==

# %%
x = 5

# %%
y = 4

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
### less than

# %%
4 < 5
# Out:
# True

# %%
3 < 8
# Out:
# True

# %%
6 < 4
# Out:
# False

# %%
### greater than

# %%
7 > 4
# Out:
# True

# %%
4 > 1
# Out:
# True

# %%
9 > 11
# Out:
# False

# %%
### equal

# %%
4 == 4
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
7 == 6
# Out:
# False

# %%
### combine the equal with either less than or greater than

# %%
5 >= 5 ### disjuction statement
# Out:
# True

# %%
7 <= 7
# Out:
# True

# %%
### negation

# %%
8 == 8
# Out:
# True

# %%
8 != 8 ## ! not
# Out:
# False

# %%
name = "deji"

# %%
gender = "male"

# %%
name != "deji"
# Out:
# False

# %%
### logical

# %%
## AND , OR , NOT

# %%
p = 3
w = 7
x = 4
y = 6

# %%
p < w
# Out:
# True

# %%
x < y
# Out:
# True

# %%
(p < w) and (x<y) ## conjuction statement
# Out:
# True

# %%
(p < w) and (x > y)
# Out:
# False

# %%
(p < w) or (x > y)
# Out:
# True

# %%
(p < w) or (x<y) ## disjuction
# Out:
# True

# %%
name = "mrs ade"

# %%
objects = "Human"

# %%
name == "mrs ade" and objects == "Human"
# Out:
# True

# %%
not True
# Out:
# False

# %%
name == "mrs ade" and not objects == "Human"
# Out:
# False

# %%
True and not True

# %%
True and False
# Out:
# False
