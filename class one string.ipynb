# %%
### Data Type

# %%
### text >>>>  string

# %%
## single quote ''
## double quote ""
## triple quote ''' '''
## triple double quote """ """

# %%
'mrs ade'
# Out:
# 'mrs ade'

# %%
"mrs ade"
# Out:
# 'mrs ade'

# %%
'''this is 
deji'''
# Out:
# 'this is \ndeji'

# %%
""""this is 
deji"""
# Out:
# '"this is \ndeji'

# %% [markdown]
# ## concantenation

# %%
"deji" + "ayo"
# Out:
# 'dejiayo'

# %%
"vivian" + "obi"
# Out:
# 'vivianobi'

# %%
"vivian " + "obi"
# Out:
# 'vivian obi'

# %%
"vivian" + " obi"
# Out:
# 'vivian obi'

# %%
"vivian" + " " + "obi"
# Out:
# 'vivian obi'

# %% [markdown]
# ### Variable name

# %%
name1 = "deji"

# %%
name1
# Out:
# 'deji'

# %%
name2 = "ayo"

# %%
name2
# Out:
# 'ayo'

# %%
name1 + " " + name2
# Out:
# 'deji ayo'

# %%
### method associated with string
