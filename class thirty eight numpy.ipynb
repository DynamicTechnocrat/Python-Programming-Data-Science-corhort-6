# %%
### numpy , pandas

# %%
pip install numpy

# %%
import numpy as np

# %%
x = [1,2,3,4,5]

type(x)
# Out:
# list

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
### converting a list to numpy array

arr = np.array(x)
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
dir(arr)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__buffer__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
# ...

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
y = [1,2,3,4.5]
y
# Out:
# [1, 2, 3, 4.5]

# %%
arr2 = np.array(y)

# %%
arr2
# Out:
# array([1. , 2. , 3. , 4.5])

# %%
arr2.dtype
# Out:
# dtype('float64')

# %%
z = [1,2,3,"deji"]
z
# Out:
# [1, 2, 3, 'deji']

# %%
arr3 = np.array(z)
arr3
# Out:
# array(['1', '2', '3', 'deji'], dtype='<U11')

# %%
arr3.dtype
# Out:
# dtype('<U11')

# %%
### working with numpy

# %%
arr4 = np.array([1,2,3,4,5,6,7,8])

# %%
arr4
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
arr4.size
# Out:
# 8

# %%
arr4.shape
# Out:
# (8,)

# %%
arr4.reshape((2,4))
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
### performance some mathematical operation

# %%
arr4 + 2
# Out:
# array([ 3,  4,  5,  6,  7,  8,  9, 10])

# %%
arr4 * 10
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80])

# %%
arr4 - 1
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
arr4 / 6
# Out:
# array([0.16666667, 0.33333333, 0.5       , 0.66666667, 0.83333333,
#        1.        , 1.16666667, 1.33333333])

# %%
type(arr4)
# Out:
# numpy.ndarray

# %%
arr4.dtype
# Out:
# dtype('int32')

# %%
#### boolean index

# %%
arr4
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
arr4 > 2
# Out:
# array([False, False,  True,  True,  True,  True,  True,  True])

# %%
arr4[arr4 > 2]### to get value where array 4  is greater than 2
# Out:
# array([3, 4, 5, 6, 7, 8])

# %%
arr4 < 5
# Out:
# array([ True,  True,  True,  True, False, False, False, False])

# %%
arr4[arr4 < 5] ### to get value where array 4  is less than 5
# Out:
# array([1, 2, 3, 4])

# %%
### statistics with numpy

# %%
arr4
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
arr4.mean()
# Out:
# 4.5

# %%
arr4.var()
# Out:
# 5.25

# %%
arr4.std()
# Out:
# 2.29128784747792

# %%
### pandas 
### two datatype >>> Series , DataFrame
