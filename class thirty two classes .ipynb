# %%
### oop

# %%
#### class , object , attribute , method

# %%
### object is an instance of a class 
### a class is a blueprint for creating an object adam
### attribute >> characteristic . name of a person , age of a person
### method >>>  fuctionalities

# %%
#### car >>>> four wheel , move 100km >>> car design  , int design 

car1 >>> four wheel and move 100km

# %%
name = "deji"

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
### class is a blueprint for creating an object eg Car
### object is an instance of a class eg Toyota camry
### attribute are characteristics or feature of an object as defined in the class eg wheel , color
### method are fuctions of an object as defined in the class , manual or auto driving

# %%
### creating a customer class , name , age , checkbalance

# %%
class Customer:
    def __init__(self, name , age):  ### defining attribute
        self.myname = name 
        self.myage = age

# %%
customer1 = Customer("mrs ade", 27)
customer1 ### is a variable that reference the object >>>>>  Customer

# %%
dir(customer1) ### fro bringing the identifier and method associated to a class
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'myage',
#  'myname']

# %%
customer1.myage
# Out:
# 27

# %%
customer1.myname
# Out:
# 'mrs ade'
