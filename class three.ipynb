# %%
x = "james"

# %%
x
# Out:
# 'james'

# %%
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
x1 = x.upper()
x1
# Out:
# 'JAMES'

# %%
p = "PAUL"

# %%
p
# Out:
# 'PAUL'

# %%
p1 = p.lower() ##paul
p1
# Out:
# 'paul'

# %%
z = "deji"

# %%
z1  = z.title()
z1
# Out:
# 'Deji'

# %%
### 
t = " deji"

# %%
t
# Out:
# ' deji'

# %%
t1 = t.lstrip()
t1
# Out:
# 'deji'

# %%
y = "dupe "

# %%
y1 = y.rstrip()

# %%
y1
# Out:
# 'dupe'

# %%
W = " james "

# %%
W1 = W.lstrip()

# %%
W2 = W1.rstrip()

# %%
W2
# Out:
# 'james'

# %%
W3 = W.strip()

# %%
W3
# Out:
# 'james'

# %%
u = "deji"

# %%
dir(u)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
## count , endswith , startswith , replace, islower , issuper

# %%
x = "barabas"

# %%
x.count("a")
# Out:
# 3

# %%
x.count("r")
# Out:
# 1

# %%
### endswith

# %%
y = "james"

# %%
y.endswith("s")
# Out:
# True

# %%
y.endswith("d")
# Out:
# False

# %%
y.startswith("p")
# Out:
# False

# %%
y.startswith("j")
# Out:
# True

# %%
### replace

# %%
t = "bello"
t
# Out:
# 'bello'

# %%
t.replace("b","h") ### t.replace(old,new)
# Out:
# 'hello'

# %%
t.islower()
# Out:
# True

# %%
t.isupper()
# Out:
# False

# %%
### True and False are called booleans

# %%
q = "5678"

# %%
q.isalpha()
# Out:
# False

# %%
q.isnumeric()
# Out:
# True

# %%
x = "james"

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
#### numbers

# %%
### 3,4,5,6 ### integers 
### 2.1,4.5 ### float

# %%
x = 3

# %%
x
# Out:
# 3

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
y = 4.5

# %%
y
# Out:
# 4.5

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
### operator numbers

# %%
4 + 6
# Out:
# 10

# %%
4 + 2.3
# Out:
# 6.3

# %%
6 - 2
# Out:
# 4

# %%
7 - 2.1
# Out:
# 4.9

# %%
4 * 2
# Out:
# 8

# %%
7 * 4
# Out:
# 28

# %%
8 / 2
# Out:
# 4.0

# %%
9 / 3
# Out:
# 3.0

# %%
4 ** 2
# Out:
# 16

# %%
4 ** 3
# Out:
# 64

# %%
6 ** 2
# Out:
# 36
