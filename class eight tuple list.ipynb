# %%
### insert , index , sort , sorted , len tuple ## immutable

# %%
x = ["deji","mrs ade","mr james","philip"]

# %%
x
# Out:
# ['deji', 'mrs ade', 'mr james', 'philip']

# %%
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
x
# Out:
# ['deji', 'mrs ade', 'mr james', 'philip']

# %%
x.index("deji")
# Out:
# 0

# %%
x.index("mr james")
# Out:
# 2

# %%
x.insert(0,"mr bade")

# %%
x
# Out:
# ['mr bade', 'deji', 'mrs ade', 'mr james', 'philip']

# %%
x.insert(1,"mrs odun")

# %%
x
# Out:
# ['mr bade', 'mrs odun', 'deji', 'mrs ade', 'mr james', 'philip']

# %%
x.pop()
# Out:
# 'philip'

# %%
x
# Out:
# ['mr bade', 'mrs odun', 'deji', 'mrs ade', 'mr james']

# %%
x.pop(0)
# Out:
# 'mr bade'

# %%
x
# Out:
# ['mrs odun', 'deji', 'mrs ade', 'mr james']

# %%
x.pop(1)
# Out:
# 'deji'

# %%
x
# Out:
# ['mrs odun', 'mrs ade', 'mr james']

# %%
x.remove("mrs odun")

# %%
x
# Out:
# ['mrs ade', 'mr james']

# %%
x.reverse()

# %%
x
# Out:
# ['mr james', 'mrs ade']

# %%
x.sort(reverse=True)

# %%
x
# Out:
# ['mrs ade', 'mr james']

# %%
y = [3,1,2,4,6,5]

# %%
y.sort()

# %%
y
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
y.sort(reverse=True)

# %%
y
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
### Tuple

# %%
### tuple is immutable

# %%
names = ("deji","ayo","bello","bello")

# %%
names
# Out:
# ('deji', 'ayo', 'bello', 'bello')

# %%
print(type(names))
# Out:
# <class 'tuple'>

# %%
dir(names)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
names.count("bello")
# Out:
# 2

# %%
names.index("deji")
# Out:
# 0

# %%
names.remove("deji")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 names.remove("deji")
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
names.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 names.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
### set and method associated
