# %%
name = "mr james"

# %%
name.upper()
# Out:
# 'MR JAMES'

# %%
names = "mrs ade"
names.upper()
# Out:
# 'MRS ADE'

# %%
names = ["deji","ayo"]

for nam in names:
    print(nam.upper())
# Out:
# DEJI
# AYO

# %%
### function keyword >>> def
### function name >>> name
### function body
### function parameter >> (input)

# %%
def greet():
    print("hello")

# %%
greet()
# Out:
# hello

# %%
def surname():
    print("bade")

# %%
surname()
# Out:
# bade

# %%
def greet(name):
    print(name)

# %%
greet("deji")
# Out:
# deji

# %%
greet("mrs ade")
# Out:
# mrs ade

# %%
greet("mr james")
# Out:
# mr james

# %%
def MODIFY(firstname):
    hold = firstname.upper()
    print(hold)

# %%
MODIFY("deji")
# Out:
# DEJI

# %%
def greet(name):
    print(f"hello {name} welcome to the service")

# %%
greet("mrs ade")
# Out:
# hello mrs ade welcome to the service

# %%
greet("mr james")
# Out:
# hello mr james welcome to the service

# %%
### add two numbers

# %%
x = 4
y = 5
x + y
# Out:
# 9

# %%
x = 5
y = 7
x + y
# Out:
# 12

# %%
def add(x,y):
    print(x + y)

# %%
add(1,3)
# Out:
# 4

# %%
add(9,3)
# Out:
# 12

# %%
def substract(x,y):
    print(x - y)

# %%
substract(9,4)
# Out:
# 5

# %%
substract(10,3)
# Out:
# 7

# %%
### *arg . **arg , keyword parameter , position default
