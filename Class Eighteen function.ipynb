# %%
def greet(firstname , secondname):
    return f"hello {firstname} {secondname}"

# %%
greet("deji","ayo")
# Out:
# 'hello deji ayo'

# %%
def greet1(firstname,secondname="marcus"):
    return f"hello {firstname} {secondname}"

# %%
greet1("deji")
# Out:
# 'hello deji marcus'

# %%
def add(x,y=0): ## x is called positional argument , y = keyword argument
    return x+y

# %%
add(3)
# Out:
# 3

# %%
### ***

# %%
def info(details):
    return details

# %%
info("deji",21)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 info("deji",21)
#
# TypeError: info() takes 1 positional argument but 2 were given

# %%
def info(**details):
    return details

# %%
info(name="deji",age=12,gender="male")
# Out:
# {'name': 'deji', 'age': 12, 'gender': 'male'}

# %%
def info(*details):
    return details

# %%
info("deji",12,"male")
# Out:
# ('deji', 12, 'male')

# %%
### lambda >> anonymous function

# %%
def add(x,y):
    return x + y

# %%
add(10,40)
# Out:
# 50

# %%
addition = lambda x,y=0 : x + y

# %%
addition(3,4)
# Out:
# 7
