# %%
x = [1,3,4]

for w in x:
    print(w)
# Out:
# 1
# 3
# 4

# %%
### webscraping

# %%
import time
gender = input("what is your gender : ") #male

while gender != "female": #True , male != female True , female != female
    print("gender is not female")
    time.sleep(2)
    gender = input("what is your gender part two : ") #male , female
# Out:
# what is your gender :  male
# gender is not female
# what is your gender part two :  male
# gender is not female
# what is your gender part two :  female

# %%
"children" != "female"
# Out:
# True

# %%
gender = "male"
if gender != "female":
    print(1)
else:
    print(2)
# Out:
# 1

# %%
while True:
    gender = input("what is your gender part three : ")
    print(gender)
    time.sleep(2)
    if gender == "male":
        print(f"we got a {gender}")
        break
# Out:
# what is your gender part three :  male
# male
# what is your gender part three :  female
# female
# what is your gender part three :  male
# male
# what is your gender part three :  male
# male
# what is your gender part three :  deji
# deji
# what is your gender part three :  5
# 5
# what is your gender part three :  quit
# quit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 while True:
# ----> 2     gender = input("what is your gender part three : ")
#       3     print(gender)
#       4     time.sleep(2)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
# ...

# %%
from datetime import datetime

# %%
datetime.now().hour
# Out:
# 20

# %%
while True:
    if datetime.now().hour == 20 and datetime.now().minute == 55:
        break
    else:
        print("its not yet time")
        time.sleep(10)
# Out:
# its not yet time
# its not yet time
# its not yet time
# its not yet time
# its not yet time
# its not yet time
