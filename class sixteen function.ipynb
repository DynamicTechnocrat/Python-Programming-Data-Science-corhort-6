# %%
### return , print , *Arg , **arg

# %%
def capitalize(name):
    print(name.upper())

# %%
capitalize("deji")
# Out:
# DEJI

# %%
q = capitalize("mr bade")
# Out:
# MR BADE

# %%
print(q)
# Out:
# None

# %%
def capitalize(name):
    return name.upper()

# %%
capitalize("dele")
# Out:
# 'DELE'

# %%
y = capitalize("bello")

# %%
y
# Out:
# 'BELLO'

# %%
y + " is a boy"
# Out:
# 'BELLO is a boy'

# %%
def lowercase(name):
    compute = name.lower()
    return compute

# %%
lowercase("MR JAMES")
# Out:
# 'mr james'

# %%
Z = lowercase("Mr PHILIP")

# %%
print(Z)
# Out:
# mr philip

# %%
## write a function that add two number together so after that take the result out of the function and add 30 to it

# %%
def add(x,y):
    return x + y

# %%
result = add(3,5)

# %%
result
# Out:
# 8

# %%
final_result = result + 30

# %%
final_result
# Out:
# 38
