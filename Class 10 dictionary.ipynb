# %%
### dictionary

# %%
names = {"deji":890,"mrs ade":672,"mr james":842}

# %%
names
# Out:
# {'deji': 890, 'mrs ade': 672, 'mr james': 842}

# %%
details = {"name":"mr james","age":21,"city":"luxemborg"}

# %%
details
# Out:
# {'name': 'mr james', 'age': 21, 'city': 'luxemborg'}

# %%
### accessing a dictionary

# %%
### key

# %%
details["name"]
# Out:
# 'mr james'

# %%
details['age']
# Out:
# 21

# %%
details['city']
# Out:
# 'luxemborg'

# %%
### methods

# %%
dir(details)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
details['name'] = "mrs ade"

# %%
details
# Out:
# {'name': 'mrs ade', 'age': 21, 'city': 'luxemborg'}

# %%
### copy

# %%
details2 = details.copy()

# %%
details2
# Out:
# {'name': 'mrs ade', 'age': 21, 'city': 'luxemborg'}

# %%
details['name'] = "mr james"

# %%
details
# Out:
# {'name': 'mr james', 'age': 21, 'city': 'luxemborg'}

# %%
details.clear()

# %%
details
# Out:
# {}

# %%
details = details2.copy()

# %%
details
# Out:
# {'name': 'mrs ade', 'age': 21, 'city': 'luxemborg'}

# %%
### method

# %%
dir(details)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
### keys , values , get , pop , update

# %%
details
# Out:
# {'name': 'mrs ade', 'age': 21, 'city': 'luxemborg'}

# %%
details.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
details.values()
# Out:
# dict_values(['mrs ade', 21, 'luxemborg'])

# %%
print(details.get("hometown","not found"))
print(2 + 2)
# Out:
# not found
# 4

# %%
details
# Out:
# {'name': 'mrs ade', 'age': 21, 'city': 'luxemborg'}

# %%
details2 = {"sibling":3,"hometown":"abuja"}

# %%
details2
# Out:
# {'sibling': 3, 'hometown': 'abuja'}

# %%
details.update(details2)

# %%
details
# Out:
# {'name': 'mrs ade',
#  'age': 21,
#  'city': 'luxemborg',
#  'sibling': 3,
#  'hometown': 'abuja'}

# %%
## pop

# %%
details.pop("name")
# Out:
# 'mrs ade'

# %%
details
# Out:
# {'age': 21, 'city': 'luxemborg', 'sibling': 3, 'hometown': 'abuja'}

# %%
details.pop("sibling")
# Out:
# 3

# %%
details
# Out:
# {'age': 21, 'city': 'luxemborg', 'hometown': 'abuja'}
