# %%
def greet(name):
    print(f"hello {name}")

# %%
user1 = greet("mrs ade")
# Out:
# hello mrs ade

# %%
print(user1)
# Out:
# None

# %%
greet("mr james")
# Out:
# 'hello mr james'

# %%
x = input("what is your name : ")
f"hello {x}"
# Out:
# what is your name :  deji
# 'hello deji'

# %%
y = input("what is your name : ")
f"hello {y}"
# Out:
# what is your name :  bola
# 'hello bola'

# %%
def greet1(name , gender):
    if gender.lower().strip() == "male":
        return f"hello mr {name}"
    else:
        return f"hello mrs {name}"

# %%
greet1("deji","male")
# Out:
# 'hello mr deji'

# %%
greet1("bola","female")
# Out:
# 'hello mrs bola'

# %%
greet1("dele","Male")
# Out:
# 'hello mr dele'

# %%
greet1("bode","MaLE")
# Out:
# 'hello mr bode'

# %%
greet1("deji","Male ")
# Out:
# 'hello mr deji'

# %%
greet1("banji","           malE           ")
# Out:
# 'hello mr banji'

# %%
### *args

# %%
def add(x,y,z):
    return x + y + z

# %%
add(3,4,5)
# Out:
# 12

# %%
add(5,2,3)
# Out:
# 10

# %%
### for loop
x = (1,2,3,4,5,6,7,8,9)

total = 0

for value in x:
    total = total + value #1
    print(total)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
total
# Out:
# 45

# %%
### for loop
x = (10,10,10)

total = 1

for value in x:
    total = total * value #1

print(total)
# Out:
# 1000

# %%
total
# Out:
# 1000

# %%
def add1(x,y=0):
    return x +y

# %%
add1(3)
# Out:
# 3

# %%
def multiply(x,y=1):
    return (x * y)

# %%
multiply(10.2,3)
# Out:
# 30.599999999999998

# %%
multiply(4)
# Out:
# 4

# %%
multiply(2,4)
# Out:
# 8

# %%
def add2(p,q,r):
    return p + q + r

# %%
add2(10,11,12,13,14,15)
# Out:
# 33

# %%
### for loop
x = (10,10,10)

total = 0

for value in x:
    total = total + value #1

print(total)

# %%
def add(*x):
    return x

# %%
add(9,3,4)
# Out:
# (9, 3, 4)

# %%
def add(*values): 
    total = 0
    for num in values:
        total = total + num
        print(total)

# %%
add(1,2,4)
# Out:
# 1
# 3
# 7

# %%
def add3(*values2):
    total = 0
    for num in values2:
        total = total + num
    print(total)

# %%
add3(10,10,20,30,40,50,60,70,80)
# Out:
# 370

# %%
def add3(*values2):
    total = 0
    for num in values2:
        total = total + num
    return total

# %%
result = add3(10,10,20,30)

# %%
result
# Out:
# 70

# %%
def greet(*names):
    return names

# %%
greet("deji","mrs ade","mr james")
# Out:
# ('deji', 'mrs ade', 'mr james')

# %%
def greet(*names):
    for the_name in names:
        print(the_name.upper())

# %%
greet("deji","mrs ade","ope")
# Out:
# DEJI
# MRS ADE
# OPE

# %%
### while loop

gender = input("what is your gender : ")

while gender != "male":
    print("gender is not male")
    gender = input("what is your gender2 : ")
# Out:
# what is your gender :  female
# gender is not male
# what is your gender2 :  female
# gender is not male
# what is your gender2 :  male

# %%
import time
while True:
    print("yes")
    time.sleep(2)
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 4
#       2 while True:
#       3     print("yes")
# ----> 4     time.sleep(2)
#
# KeyboardInterrupt:
