# %%
### startswith , endswith ,count , replace .

# %%
name = "mrs ade"

# %%
name
# Out:
# 'mrs ade'

# %%
name.startswith("mrs")
# Out:
# True

# %%
name.startswith("pa")
# Out:
# False

# %%
### endswith

# %%
name2 = "mr ezekiel"

# %%
name2.endswith("el")
# Out:
# True

# %%
name2.endswith("de")
# Out:
# False

# %%
#### count

# %%
name3 = "barabas"

# %%
name3.count("a")
# Out:
# 3

# %%
name3.count("b")
# Out:
# 2

# %%
statement = "deji ayo deji dupe shade"

# %%
statement.count("deji")
# Out:
# 2

# %%
statement.count("ayo")
# Out:
# 1

# %%
### replace

# %%
name4 = "mr james"

# %%
name4
# Out:
# 'mr james'

# %%
name4.replace("mr","mrs")
# Out:
# 'mrs james'

# %%
name4
# Out:
# 'mr james'

# %%
### how to recieve input from users

# %%
name5 = input("what is your name : ")
# Out:
# what is your name :  deji

# %%
name5
# Out:
# 'deji'

# %%
name7 = "dolapo"

# %%
name7
# Out:
# 'dolapo'

# %%
len(name7)
# Out:
# 6

# %%
### index and slicing formatted string

# %%
name8 = "philip"

# %%
### index

# %%
name8[0]
# Out:
# 'p'

# %%
name8[1]
# Out:
# 'h'

# %%
name8[3]
# Out:
# 'l'

# %%
name8[3]
# Out:
# 'l'

# %%
### slicing

# %%
name9 = "favour"

# %%
name9
# Out:
# 'favour'

# %%
name9[0:3]
# Out:
# 'fav'

# %%
name9[0:2]
# Out:
# 'fa'

# %%
name9[-1]
# Out:
# 'r'

# %%
name9[-2]
# Out:
# 'u'

# %%
name9[-3]
# Out:
# 'o'

# %%
### step for slicing , formatted string , numbers (int , float) work with
