# %%
name = "deji"

# %%
name
# Out:
# 'deji'

# %%
name1 = "MR JAMES"

# %%
name1
# Out:
# 'MR JAMES'

# %%
name2 = "TolA"

# %%
name2
# Out:
# 'TolA'

# %%
type("deji")
# Out:
# str

# %%
### method

# %%
### dir

# %%
dir("mrs ade")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
name3 = "shade"

# %%
name3
# Out:
# 'shade'

# %%
name4 = name3.upper()

# %%
name4
# Out:
# 'SHADE'

# %%
name = "mrs ade"

# %%
name.upper()
# Out:
# 'MRS ADE'

# %%
name2 = name.upper()

# %%
name2
# Out:
# 'MRS ADE'

# %%
name5 = "MR JAMES"

# %%
name5.lower()
# Out:
# 'mr james'

# %%
name6 = name5.lower()

# %%
name6
# Out:
# 'mr james'

# %%
name7 = "deji"

# %%
name7.title()
# Out:
# 'Deji'

# %%
name8 = name7.title()

# %%
name8
# Out:
# 'Deji'

# %%
### removing space

# %%
name9 = " mrs ade"

# %%
name9.lstrip()
# Out:
# 'mrs ade'

# %%
name10 = name9.lstrip()

# %%
name10
# Out:
# 'mrs ade'

# %%
name11 = "mr james "

# %%
name11
# Out:
# 'mr james '

# %%
name11.rstrip()
# Out:
# 'mr james'

# %%
name12 = name11.rstrip()

# %%
name12
# Out:
# 'mr james'

# %%
name13 = " mrs ade "

# %%
name13.lstrip()
# Out:
# 'mrs ade '

# %%
name14 = name13.lstrip()

# %%
name14
# Out:
# 'mrs ade '

# %%
name14.rstrip()
# Out:
# 'mrs ade'

# %%
name13.strip()
# Out:
# 'mrs ade'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
### isupper , islower , startswith , endswith , count ,replace

# %%
name15 = "mrs ade"

# %%
name15.islower()
# Out:
# True

# %%
name15.isupper()
# Out:
# False

# %%
name16 = "I AM A BOY"

# %%
name16.islower()
# Out:
# False

# %%
name16.isupper()
# Out:
# True

# %%
details = "deji"

# %%
dir(details)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
details.isalpha()
# Out:
# True

# %%
data = "1234"

# %%
type(data)
# Out:
# str

# %%
data.isnumeric()
# Out:
# True

# %%
"10" + "5"
# Out:
# '105'

# %%
10 + 5
# Out:
# 15

# %%
### startswith , endswith ,count , replace .
