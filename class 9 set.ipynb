# %%
### [] , ()

# %%
x = (5,6)

# %%
type(x)
# Out:
# tuple

# %%
y = 7 , 8

# %%
y
# Out:
# (7, 8)

# %%
type(y)
# Out:
# tuple

# %%
z = "deji","ayo"

# %%
z
# Out:
# ('deji', 'ayo')

# %%
type(z)
# Out:
# tuple

# %%
### set

# %%
### properties

# %%
### no repetition , 1,1,1,1 >>> 1

# %%
x = {2,1,4,5,3,3,1,1,1,1,1,1}

# %%
x
# Out:
# {1, 2, 3, 4, 5}

# %%
### method associated with a set

# %%
dir(x)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
y = {3,4,5,6,7,8}

# %%
y.add(9)

# %%
y
# Out:
# {3, 4, 5, 6, 7, 8, 9}

# %%
y.add(10)

# %%
y
# Out:
# {3, 4, 5, 6, 7, 8, 9, 10}

# %%
y.clear()

# %%
y
# Out:
# set()

# %%
x = {1,2,3,4,5}
y = {4,6,7,8,9}

# %%
x.difference(y)
# Out:
# {1, 2, 3, 5}

# %%
y.difference(x)
# Out:
# {6, 7, 8, 9}

# %%
x = {"task a","task b","task c"} ### done

# %%
y = {"task a","task d","task e"}

# %%
y.difference(x)
# Out:
# {'task d', 'task e'}

# %%
y
# Out:
# {'task d', 'task e'}

# %%
p = {"deji","ayo","mrs ade","mr james"}
q = {"ayo","bola","philip"}

# %%
p.difference(q)
# Out:
# {'deji', 'mr james', 'mrs ade'}

# %%
p.intersection(q)
# Out:
# {'ayo'}

# %%
p.union(q)
# Out:
# {'ayo', 'bola', 'deji', 'mr james', 'mrs ade', 'philip'}

# %%
p
# Out:
# {'ayo', 'deji', 'mr james', 'mrs ade'}

# %%
q
# Out:
# {'ayo', 'bola', 'philip'}

# %%
p.update(q)

# %%
p
# Out:
# {'ayo', 'bola', 'deji', 'mr james', 'mrs ade', 'philip'}

# %%
###

# %%
x = {"mr james","mrs ade","deji"}
y = {"deji","bola"}

# %%
x.difference(y)
# Out:
# {'mr james', 'mrs ade'}

# %%
x
# Out:
# {'deji', 'mr james', 'mrs ade'}

# %%
x.difference_update(y)

# %%
x
# Out:
# {'mr james', 'mrs ade'}

# %%
### 50 questions
